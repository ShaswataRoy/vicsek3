# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('default')

# %%
sigma = np.linspace(0.,0.5,5)

# %%
P1 = np.exp(-sigma**2/2)
P2 = np.exp(-2*sigma**2)
P3 = np.exp(-9*sigma**2/2)
P4 = np.exp(-16*sigma**2/2)

# %%
rho = .125

# %%
mu = (8/np.pi)*((2*np.sqrt(2)-1)*P2/3 - 7/5)*rho-1+P2
eta = (32/(35*np.pi))*(1/15+P4)*(13/9-(6*np.sqrt(2)+1)*P2/np.pi)
eta = eta/((8/(3*np.pi))*(31/21+P4/5)*rho+1-P4)

# %%
mu/eta
# Out:
# 0.022444141619192788

# %%
plt.plot(sigma,np.sqrt(mu/etz))

# %%
rho = .4
lam = .2
sigma0=1
sigma = np.linspace(0,5,5)

P1 = np.exp(-sigma**2/2)
P0 = np.exp(-sigma0**2/2)

mu = (4/np.pi)*(P1-2/3)+lam*(1-P0)
nu = 1/(lam*(1-P0**2)+(4/np.pi)*rho*(14/15+2*P1**2/3))
eta = (64*nu/(np.pi**2))*(P1-2/5)*(1/3+P1**2)

# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('default')
#Extract Data
x,y = np.loadtxt('boltzmann_100.txt',delimiter='\t',unpack=True)
x1,y1 = np.loadtxt('boltzmann_60.txt',delimiter='\t',unpack=True)
x2,y2 = np.loadtxt('boltzmann_40.txt',delimiter='\t',unpack=True)

# %%
plt.plot(x,y,label='N=100')
plt.plot(x1,y1,label='N=60')
plt.plot(x2,y2,label='N=40')
plt.legend()

# %%
rho = 1
mu = (8/np.pi)*((2*np.sqrt(2)-1)*P2/3-7/5)*rho-1+P2
eta = (32/(35*np.pi))*(1/15+P4)*(13/9-(6*np.sqrt(2)+1)*P2/np.pi)/((8/(3*np.pi))*(31/21+P4/5)*rho+1-P4)

# %%
plt.plot(sigma,np.sqrt(mu/eta))

# %%
lam = 1
P20 = np.exp(-2)
P10 = np.exp(-0.5)
nu = 0.25/((1-P20)+(4*rho/np.pi)*(14/15+2*P2/3))
mu = (4*rho/np.pi)*(P1-2/3)-(1-P10)
eta = (64*nu/(np.pi**2))*(P1-0.4)*(1/3+P2)

# %%
plt.plot(sigma,np.sqrt(mu/eta))
